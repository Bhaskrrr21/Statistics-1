# %% [markdown]
# # Statistics Advance Part 1

# %% [markdown]
# 1. What is a random variable in probability theory ?
# - A random variable is something that gives you a number based on the result of a random experiment.
#
# For example:
# When you toss a coin, if you say Heads = 1 and Tails = 0, the result is a random variable.

# %% [markdown]
# 2. What are the types of random variables ?
# - Discrete Random Variables:
#
# These variables can take on a countable number of distinct values.
#
# Example : The outcome of rolling a die (which can be 1, 2, 3, 4, 5, or 6).
#
# - Continuous Random Variables:
#
# These variables can take on an infinite number of possible values within a given range.
#
#  Example : include the height of individuals, the time it takes to run a marathon, or the temperature in a city.

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions ?
# - Discrete Distributions:
#
# Discrete distributions are associated with discrete random variables, which can take on a countable number of distinct values.
#
# Examples include the number of students in a classroom, the outcome of rolling a die.
# - Continuous Distributions:
#
# Continuous distributions are associated with continuous random variables, which can take on an infinite number of values within a given range.
#
# Examples include the height of individuals, the time it takes to complete a task, or the temperature in a city.

# %% [markdown]
# 4. What are probability distribution functions (PDF) ?
# - Probability Distribution Functions (PDFs) are mathematical functions that describe the likelihood of a random variable taking on a particular value or falling within a specific range of values.
#
# - The concept of a PDF applies to continuous random variables, while discrete random variables are described using Probability Mass Functions (PMFs)

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF) ?
# - The PDF provides the density of probabilities for specific values, while the CDF provides cumulative probabilities up to a certain value.
# - The PDF is used to describe the distribution of a continuous random variable and to calculate probabilities over intervals
# - The CDF is used to determine the probability that a random variable takes on a value less than or equal to a specific point
# - The PDF is typically represented as a curve on a graph, where the x-axis represents the values of the random variable and the y-axis represents the density of probability.
# - The CDF is represented as a non-decreasing curve that starts at 0 and approaches 1. It shows the cumulative probability up to a certain value

# %% [markdown]
# 6. What is a discrete uniform distribution ?
# - A discrete uniform distribution is a type of probability distribution in which a finite number of outcomes are equally likely to occur.
# - It is characterized by its equal probabilities, straightforward PMF, and easily computable mean and variance.

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution ?
# - The Bernoulli distribution describes a random experiment with exactly two outcomes: Success (1) or Failure (0).
# - The mean (or expected value) of a Bernoulli random variable ( X ) is given by: [ E(X) = p ] This represents the probability of success.
# - The variance of a Bernoulli random variable ( X ) is given by: [ \text{Var}(X) = p(1 - p) ]
# - The Bernoulli distribution is widely used in various fields, including:
#  - Quality control: to model the success or failure of a product.
#  - Survey analysis: to model yes/no responses.

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability ?
# - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success. It is widely used in statistics and probability theory to analyze situations where there are two possible outcomes (success or failure) across multiple trials.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied ?
#
# - The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events occur with a known constant mean rate and are independent of the time since the last event.
# - It is particularly useful for modeling rare or infrequent events and has a wide range of applications across various fields, including telecommunications, traffic analysis, natural events, and quality control

# %% [markdown]
# 10. What is a continuous uniform distribution ?
# - A continuous uniform distribution is a type of probability distribution in which all outcomes in a specified interval are equally likely to occur. This distribution is characterized by its simplicity

# %% [markdown]
# 11. What are the characteristics of a normal distribution ?
#
# The characteristics of a normal distribution are ▶
# - Bell-shaped and symmetric about the mean.
# - Mean, Median, Mode	All are equal and located at the center of the distribution.
# - Two parameters: Mean (
# 𝜇
# ) and Standard Deviation (
# 𝜎
# ).
# - Range	The variable can take any real value from
# −∞ to +∞
# - Perfectly symmetric about the mean (
# 𝜇
# ).

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important ?
# - The Standard Normal Distribution is a special case of the normal distribution where:
#
#  Mean (
# 𝜇
# ) = 0
#
#  Standard Deviation (
# 𝜎
# ) = 1
# - Simplifies Calculations:
# Instead of dealing with any normal distribution with any mean and standard deviation, we convert it to standard normal using Z-score
# - Z-tables (or standard normal tables) provide the probabilities associated with z-scores. These tables are widely used in statistics to find probabilities and critical values for hypothesis testing.

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics ?
# - The Central Limit Theorem (CLT) is a fundamental theorem in statistics that describes the behavior of the sampling distribution of the sample mean (or sum) as the sample size increases.
# - Its importance lies in its foundational role in inferential statistics, enabling researchers to make valid inferences about populations based on sample data, and providing a basis for the application of normal distribution techniques in statistical analysis.

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution ?
# - The Central Limit Theorem tells us that if we take enough samples from any population, the averages of those samples will form a normal distribution. This is important because it allows us to use the normal distribution to make statistical conclusions about the population based on sample data

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing ?
# - Z statistics are commonly used in hypothesis testing, particularly when dealing with large sample sizes or when the population standard deviation is known.
# - Testing Population Means: When you want to test hypotheses about the mean of a population, you can use the Z statistic if the sample size is large (typically n > 30) or if the population is normally distributed
# - Testing Population Proportions: Z statistics can also be used to test hypotheses about population proportions.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent ?
# - A Z-score tells you how many standard deviations a particular data point is from the mean of the distribution.
# - Formula to Calculate Z-score
#
#  Z=
# X−μ/
# ​σ
#
#
# Where:
#
#
# X = Your data point (observation)
#
#
# μ = Mean of the population
#
#
# σ = Standard deviation of the population

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics ?
# - Point Estimates: Provide a single value estimate of a population parameter They are simple but do not convey uncertainty.
#
# - Interval Estimates: Provide a range of values (confidence interval) that likely contains the population parameter, along with a specified level of confidence

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis ?
# - Confidence intervals are significant in statistical analysis because they provide a range of plausible values for population parameters, quantify uncertainty, facilitate statistical inference, guide decision-making, enable comparative analysis, and enhance the communication of results.

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval ?
# - The relationship between Z-scores and confidence intervals is that Z-scores are used to determine the critical values that define the boundaries of confidence intervals. The Z-score reflects how many standard deviations away from the mean the interval extends, allowing researchers to quantify the uncertainty associated with their estimates of population parameters

# %% [markdown]
# 20. How are Z-scores used to compare different distributions ?
# - Z-scores are a powerful tool for comparing different distributions because they standardize data points, allowing for meaningful comparisons across different scales and distributions
# - A Z-score indicates how many standard deviations a particular data point is from the mean of its distribution
# - Since the formula for a Z-score is: Z=
# X−μ/
# ​σ
#
#    The unit of measurement is removed.
#
#   All values are converted to a common standard scale

# %% [markdown]
# 21. What are the assumptions for applying the Central Limit Theorem ?
# - Independence of Observations: The sampled observations must be independent.
# - Random Sampling: The sample should be drawn randomly from the population.
# - Sample Size: The sample size should be sufficiently large (typically n ≥ 30), although smaller sizes may be acceptable for normal populations.
# - Finite Variance: The population must have a finite variance

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution ?
# - The expected value is a fundamental concept in probability and statistics that represents the average or mean value of a random variable in a probability distribution. It provides a measure of the center of the distribution and is a key concept in decision-making under uncertainty.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable ?
# - A probability distribution provides a mathematical framework for describing the likelihood of different outcomes of a random variable. It essentially characterizes how probabilities are assigned to the possible values that the random variable can take.Together, they are essential for understanding and analyzing random processes in various fields, including statistics, finance, and science.

# %% [markdown]
# # Practical

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value ?

# %%
import random

random_number = random.randint(1, 100)

print("Generated Random Number:", random_number)
# Out:
# Generated Random Number: 97

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF) ?

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

a, b = 1, 10

random_variable = randint.rvs(a, b+1, size=1000)

x = np.arange(a, b+1)

pmf = randint.pmf(x, a, b+1)
plt.bar(x, pmf, width=0.5, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution ?

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the Bernoulli Probability Density Function (PDF).
    Parameters:
    - x (int): Outcome (0 or 1)
    - p (float): Probability of success (0 ≤ p ≤ 1)

    Returns:
    - float: Probability P(X = x)
    """
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        raise ValueError("x must be 0 or 1 in a Bernoulli distribution")

# Example usage
p = 0.7  # Probability of success
print(bernoulli_pdf(1, p))  # Output: 0.7 (P(X=1))
print(bernoulli_pdf(0, p))  # Output: 0.3 (P(X=0))

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 10000  # Number of simulations

# Simulating the binomial distribution
samples = np.random.binomial(n, p, size)

# Plotting the histogram
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(-0.5, n+1.5, 1), density=True, alpha=0.7, color='blue', edgecolor='black')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python ?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
lambda_ = 2  # Mean number of events
size = 10000  # Number of simulations

samples = np.random.poisson(lambda_, size)

plt.figure(figsize=(10, 5))
plt.hist(samples, bins=np.arange(min(samples)-0.5, max(samples)+1.5, 1), density=True, alpha=0.7, color='blue', edgecolor='black')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_})')
plt.xticks(range(min(samples), max(samples)+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution ?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low, high, size = 1, 10, 1000

# Simulating and computing CDF
samples = np.random.randint(low, high + 1, size)
values, cdf = np.unique(samples, return_counts=True)
cdf = np.cumsum(cdf) / size

# Plotting
plt.figure(figsize=(4, 5))
plt.step(values, cdf, where='mid', color='blue', linewidth=2, label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution')
plt.xticks(range(low, high + 1))
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
low, high, size = 0, 1, 1000

samples = np.random.uniform(low, high, size)

plt.hist(samples, bins=13, density=True, alpha=0.7, color='black', edgecolor='yellow')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
#  8. Simulate data from a normal distribution and plot its histogram ?

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma, sample_size = 0, 1, 1000

samples = np.random.normal(mu, sigma, sample_size)

plt.figure(figsize=(8, 5))
plt.hist(samples, bins=40, density=True, alpha=0.6, color='green', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Normal Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them ?

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_z_scores(data):
    mean, std_dev = np.mean(data), np.std(data)
    z_scores = (data - mean) / std_dev

    plt.figure(figsize=(8, 5))
    plt.hist(z_scores, bins=30, density=True, alpha=0.7, color='purple', edgecolor='black')
    plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label='Mean (Z=0)')
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.title('Z-score Distribution')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    return z_scores

# Generate normal distribution samples
samples = np.random.normal(0, 1, 1000)

# Calculate and plot Z-scores
z_scores = plot_z_scores(samples)

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def central_limit_theorem_demo(sample_size, num_samples):

    np.random.seed(82)

    # Generate multiple samples from an exponential distribution
    means = [np.mean(np.random.exponential(scale=2, size=sample_size)) for _ in range(num_samples)]

    sns.histplot(means, bins=30, kde=True, color='orange')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.title(f'Central Limit Theorem Demonstration (n={sample_size})')
    plt.show()

# Test CLT with different samples
for n in [5, 10, 50]:
    central_limit_theorem_demo(sample_size=n, num_samples=1000)

# %% [markdown]
#  11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parameters
mu, sigma, sample_size, num_samples = 50, 15, 30, 1000

# Generate sample means
sample_means = np.mean(np.random.normal(mu, sigma, (num_samples, sample_size)), axis=1)

# Plot histogram
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Overlay normal distribution
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma / np.sqrt(sample_size)), 'r', linewidth=2, label='Theoretical Normal')

# Labels and title
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Distribution of Sample Means (Central Limit Theorem)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1) ?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():

    x = np.linspace(-4, 4, 1000)

    # Compute the standard normal PDF
    y = norm.pdf(x, loc=0, scale=1)

    # Plot
    plt.figure(figsize=(7, 5))
    plt.plot(x, y, label='Standard Normal Distribution', color='blue')
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (Mean = 0, Std = 1)')
    plt.legend()
    plt.grid()
    plt.show()

plot_standard_normal()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def binomial_distribution(n, p, size=1000):
    binomial_samples = np.random.binomial(n, p, size)
    unique, counts = np.unique(binomial_samples, return_counts=True)
    probabilities = counts / size

    plt.bar(unique, probabilities, color='g', alpha=0.6, edgecolor='black')
    plt.xlabel("Number of Successes")
    plt.ylabel("Probability")
    plt.title(f"Binomial Distribution (n={n}, p={p})")
    plt.grid()
    plt.show()

    return dict(zip(unique, probabilities))

# Example
binomial_distribution(15, 0.5)
# Out:
# {np.int64(2): np.float64(0.004),
#  np.int64(3): np.float64(0.008),
#  np.int64(4): np.float64(0.044),
#  np.int64(5): np.float64(0.093),
#  np.int64(6): np.float64(0.151),
#  np.int64(7): np.float64(0.203),
#  np.int64(8): np.float64(0.191),
#  np.int64(9): np.float64(0.153),
#  np.int64(10): np.float64(0.089),
#  np.int64(11): np.float64(0.045),
#  np.int64(12): np.float64(0.016),
#  np.int64(13): np.float64(0.003)}

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Function to calculate Z-score
def calculate_z_score(data, mean=None, std_dev=None):
    if mean is None:
        mean = np.mean(data)
    if std_dev is None:
        std_dev = np.std(data, ddof=1)  # Sample standard deviation
    return [(x - mean) / std_dev for x in data]

def plot_z_scores(data):
    z_scores = calculate_z_score(data)

    x = np.linspace(-4, 4, 100)
    y = stats.norm.pdf(x, 0, 1)

    plt.plot(x, y, 'b', linewidth=2, label='Standard Normal Distribution')
    for z in z_scores:
        plt.axvline(z, color='r', linestyle='dashed', alpha=0.5)

    plt.xlabel("Z-score")
    plt.ylabel("Density")
    plt.title("Z-scores Compared to Standard Normal Distribution")
    plt.legend()
    plt.grid()
    plt.show()

    return z_scores

# Example
data = [45, 50, 55, 60, 65]
z_scores = plot_z_scores(data)
print("Z-scores:", z_scores)
# Out:
# Z-scores: [np.float64(-1.2649110640673518), np.float64(-0.6324555320336759), np.float64(0.0), np.float64(0.6324555320336759), np.float64(1.2649110640673518)]

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Function to calculate Z-score
def calculate_z_score(x, mean, std_dev):
    return (x - mean) / std_dev

# Function to perform hypothesis testing using Z-statistics
def hypothesis_test(sample_mean, population_mean, std_dev, sample_size, alpha=0.05):
    z_stat = (sample_mean - population_mean) / (std_dev / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    print(f"Z-statistic: {z_stat:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to reject the null hypothesis (H0): No significant difference detected.")

    return z_stat, p_value

# Example
sample_mean = 55
population_mean = 50
std_dev = 10
sample_size = 30
hypothesis_test(sample_mean, population_mean, std_dev, sample_size)
# Out:
# Z-statistic: 2.74
# P-value: 0.0062
# Reject the null hypothesis (H0): Significant difference detected.
# (np.float64(2.7386127875258306), np.float64(0.0061698993205441255))

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result ?

# %%
import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(data, confidence_level=0.95):

    data = np.array(data)

    # Calculate the sample mean and standard error
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    n = len(data)  # Sample size
    standard_error = sample_std / np.sqrt(n)

    critical_value = stats.t.ppf((1 + confidence_level) / 2, df=n-1)  # t-distribution

    # Calculate the margin of error
    margin_of_error = critical_value * standard_error

    # Calculate the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example
if __name__ == "__main__":

    data = [10,20,30,40,50]

    # Calculate the confidence interval
    confidence_level = 0.95
    ci_lower, ci_upper = calculate_confidence_interval(data, confidence_level)

    print(f"Confidence Interval ({confidence_level*100:.0f}%): [{ci_lower:.2f}, {ci_upper:.2f}]")
# Out:
# Confidence Interval (95%): [10.37, 49.63]

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean ?

# %%
import numpy as np
import scipy.stats as stats

# Function to generate data from a normal distribution
def generate_normal_data(mean, std_dev, size):
    return np.random.normal(mean, std_dev, size)

# Function to calculate confidence interval
def confidence_interval(sample, confidence=0.95):
    mean = np.mean(sample)
    std_err = stats.sem(sample)  # Standard error of the mean
    margin = stats.t.ppf((1 + confidence) / 2, df=len(sample)-1) * std_err
    ci = (mean - margin, mean + margin)
    print(f"{confidence*100:.1f}% Confidence Interval: {ci}")
    return ci

# Generate data
np.random.seed(42)
data = generate_normal_data(50, 10, 30)

# Calculate and interpret confidence interval
ci = confidence_interval(data)
print(f"The true mean is likely within {ci[0]:.2f} to {ci[1]:.2f} with 95% confidence.")
# Out:
# 95.0% Confidence Interval: (np.float64(44.75785181035169), np.float64(51.47921027262756))
# The true mean is likely within 44.76 to 51.48 with 95% confidence.

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution ?

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Function to compute and plot the Probability Density Function (PDF) of a normal distribution
def plot_normal_pdf(mean=0, std_dev=1):
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
    y = stats.norm.pdf(x, mean, std_dev)

    plt.plot(x, y, 'b', label=f'Normal Distribution (mean={mean}, std={std_dev})')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.title('Probability Density Function (PDF)')
    plt.legend()
    plt.grid()
    plt.show()

# Example
plot_normal_pdf(5, 10)

# %% [markdown]
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution ?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the mean occurrence rate (lambda)
lambda_ = 4

# Define the range of values
k_values = np.arange(0, 15)

# Compute the CDF for each k
cdf_values = poisson.cdf(k_values, lambda_)

# Display the results
for k, cdf in zip(k_values, cdf_values):
    print(f"P(X ≤ {k}) = {cdf:.4f}")

# Plot the CDF
plt.step(k_values, cdf_values, where="post", marker="o", color="b", label=f"Poisson CDF (λ={lambda_})")
plt.xlabel("k (Number of occurrences)")
plt.ylabel("P(X ≤ k)")
plt.title("Cumulative Distribution Function (CDF) of Poisson Distribution")
plt.grid()
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value ?

# %%
import numpy as np

def simulate_uniform_distribution(a, b, size):

    return np.random.uniform(a, b, size)

def calculate_expected_value(a, b):

    return (a + b) / 2

# Example
if __name__ == "__main__":
    a = 0  # Lower bound
    b = 10  # Upper bound
    size = 1000

    samples = simulate_uniform_distribution(a, b, size)

    expected_value = calculate_expected_value(a, b)

    print(f"Generated Samples: {samples[:10]}...")
    print(f"Expected Value: {expected_value:.2f}")
# Out:
# Generated Samples: [6.84233027 4.40152494 1.22038235 4.9517691  0.34388521 9.09320402
#  2.58779982 6.62522284 3.11711076 5.20068021]...
# Expected Value: 5.00

# %% [markdown]
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference ?

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_data(mean, std_dev, size):

    return np.random.normal(loc=mean, scale=std_dev, size=size)

def calculate_standard_deviation(data):

    return np.std(data, ddof=1)  # Sample standard deviation

def plot_standard_deviations(std_devs, labels):

    plt.figure(figsize=(8, 5))
    plt.bar(labels, std_devs, color=['blue', 'orange'])
    plt.title('Comparison of Standard Deviations', fontsize=16)
    plt.xlabel('Datasets', fontsize=12)
    plt.ylabel('Standard Deviation', fontsize=12)
    plt.ylim(0, max(std_devs) + 1)  # Set y-axis limit
    plt.grid(axis='y')
    plt.show()

# Example
if __name__ == "__main__" :

    dataset1 = generate_data(mean=50, std_dev=10, size=1000)
    dataset2 = generate_data(mean=60, std_dev=20, size=1000)

    # Calculate standard deviations
    std_dev1 = calculate_standard_deviation(dataset1)
    std_dev2 = calculate_standard_deviation(dataset2)

    print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

    # Plot the standard deviations
    plot_standard_deviations([std_dev1, std_dev2], ['Dataset 1', 'Dataset 2'])
# Out:
# Standard Deviation of Dataset 1: 9.92
# Standard Deviation of Dataset 2: 20.15

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution ?

# %%
import numpy as np

np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std Dev=10

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate IQR
Q1 = np.percentile(data, 5)
Q3 = np.percentile(data, 15)
IQR = Q3 - Q1

print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
# Out:
# Range: 70.94
# Interquartile Range (IQR): 5.40

# %% [markdown]
# 23. Implement Z-score normalization on a dataset and visualize its transformation ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def generate_data(mean, std_dev, size):

    return np.random.normal(loc=mean, scale=std_dev, size=size)

def z_score_normalization(data):

    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)
    normalized_data = (data - mean) / std_dev
    return normalized_data

def plot_data(original_data, normalized_data):

    plt.figure(figsize=(12, 6))

    # Plot original data
    plt.subplot(1, 2, 1)
    sns.histplot(original_data, bins=30, kde=True, color='blue', alpha=0.6)
    plt.title('Original Data Distribution')
    plt.xlabel('Value')
    plt.ylabel('Frequency')

    # Plot normalized data
    plt.subplot(1, 2, 2)
    sns.histplot(normalized_data, bins=30, kde=True, color='orange', alpha=0.6)
    plt.title('Z-Score Normalized Data Distribution')
    plt.xlabel('Z-Score')
    plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()

# Example
if __name__ == "__main__":

    mean = 100
    std_dev = 15
    size = 1000
    original_data = generate_data(mean, std_dev, size)

    # Normalize the dataset
    normalized_data = z_score_normalization(original_data)

    plot_data(original_data, normalized_data)

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution ?

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def generate_data(mean, std_dev, size):

    return np.random.normal(loc=mean, scale=std_dev, size=size)

def calculate_skewness_kurtosis(data):

    skewness = skew(data)  # Calculate skewness
    kurt = kurtosis(data)  # Calculate kurtosis
    return skewness, kurt

if __name__ == "__main__":

    mean = 100
    std_dev = 15
    size = 1000

    # Calculate skewness and kurtosis
    skewness, kurt = calculate_skewness_kurtosis(data)

    print(f"Skewness of the dataset: {skewness:.4f}")
    print(f"Kurtosis of the dataset: {kurt:.4f}")
# Out:
# Skewness of the dataset: -0.0493
# Kurtosis of the dataset: 0.0521
